# %% [markdown]
# ## Q2 Modelling 2020

# %%
#import necessary libraries and files 
import pandas as pd
import numpy as np
import warnings
import time
import datetime as dt
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import folium
import sklearn
import seaborn as sns

from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans


# %matplotlib inline

# %%
import os
import glob
from pathlib import Path

# %%
home = str(Path.home())

os.getcwd()
old_dir = os.getcwd()
print(os.getcwd())
# Out:
# C:\Users\imeld\work\ML-Project

# %%
# constant value switches
MAKE_FILES=True
READ_FILES = True
FILE_MASK = "dublinbikes*.csv"
#FILE_MASK = "dublinbikes_2021*.csv"

# %%
#full_data.to_csv("data/full_data.csv", index= False)

# %%
# write out full data to csv file
#if MAKE_FILES : full_data.to_csv("data/full_data.csv", index= False)
#if READ_FILES : full_data = pd.read_csv("data/full_data.csv")
data = pd.read_csv("data/station_data.csv")

print(data.sample(3))
# Out:
#         STATION ID                 TIME         LAST UPDATED          NAME  \
# 560226          68  2020-10-16 13:35:02  2020-10-16 13:27:13  HANOVER QUAY
# 388992          68  2019-01-10 23:40:02  2019-01-10 23:30:34  HANOVER QUAY
# 607584          68  2021-03-30 08:05:03  2021-03-30 07:55:04  HANOVER QUAY
#
#         BIKE STANDS  AVAILABLE BIKE STANDS  AVAILABLE BIKES STATUS  \
# 560226           40                     23               17   Open
# 388992           40                     40                0   Open
# 607584           40                     29               11   Open
#
#              ADDRESS   LATITUDE  LONGITUDE  include  cluster
# 560226  Hanover Quay  53.344116  -6.237153     True      0.0
# 388992  Hanover Quay  53.344116  -6.237153     True      0.0
# 607584  Hanover Quay  53.344116  -6.237153     True      0.0

# %%
print(data.columns.values)
print(data['NAME'].unique())
# Out:
# ['STATION ID' 'TIME' 'LAST UPDATED' 'NAME' 'BIKE STANDS'
#  'AVAILABLE BIKE STANDS' 'AVAILABLE BIKES' 'STATUS' 'ADDRESS' 'LATITUDE'
#  'LONGITUDE' 'include' 'cluster' 'usage']
#          STATION ID                 TIME         LAST UPDATED  \
# 1387980          30  2018-09-25 18:25:02  2018-09-25 18:23:35
# 1210987          66  2020-06-16 03:35:02  2020-06-16 03:30:14
# 52314            89  2019-01-31 01:00:02  2019-01-31 00:50:59
#
#                             NAME  BIKE STANDS  AVAILABLE BIKE STANDS  \
# 1387980     PARNELL SQUARE NORTH           20                     16
# 1210987         NEW CENTRAL BANK           40                     19
# 52314    FITZWILLIAM SQUARE EAST           40                     40
#
#          AVAILABLE BIKES STATUS                  ADDRESS   LATITUDE  \
# 1387980                4   Open     Parnell Square North  53.353462
# 1210987               21   Open         New Central Bank  53.347122
# 52314                  0   Open  Fitzwilliam Square East  53.335213
#
#          LONGITUDE  include  cluster  usage
# 1387980  -6.265305     True      2.0    1.0
# 1210987  -6.234749     True      1.0    0.0
# 52314    -6.250900     True      0.0    0.0
# ['FITZWILLIAM SQUARE EAST' 'HANOVER QUAY' 'MATER HOSPITAL'
#  'NEW CENTRAL BANK' 'PARNELL SQUARE NORTH' 'YORK STREET EAST']

# %%
data['usage'] = abs(data['AVAILABLE BIKES'].diff())

# %%
#To estimate how the city-bike usage would have been without the pandemic (e.g., 2020)

# %%
data = data.sort_values(by=['NAME', 'LAST UPDATED'], ascending = False)

# %%
data.to_csv("data/station_data.csv", index = False)

# %%
pd.crosstab(index=data['NAME'], columns = data['cluster'] )
# Out:
# ['FITZWILLIAM SQUARE EAST' 'HANOVER QUAY' 'MATER HOSPITAL'
#  'NEW CENTRAL BANK' 'PARNELL SQUARE NORTH' 'YORK STREET EAST']
# cluster                     0.0     1.0     2.0
# NAME
# FITZWILLIAM SQUARE EAST  342454       0       0
# HANOVER QUAY             343626       0       0
# MATER HOSPITAL                0       0  342870
# NEW CENTRAL BANK              0  343200       0
# PARNELL SQUARE NORTH          0       0  343825
# YORK STREET EAST              0  343681       0

# %%
data.describe()
#data.head()
# Out:
#          STATION ID   BIKE STANDS  AVAILABLE BIKE STANDS  AVAILABLE BIKES  \
# count  2.059656e+06  2.059656e+06           2.059656e+06     2.059656e+06
# mean   6.380978e+01  3.532643e+01           2.377723e+01     1.144030e+01
# std    1.889043e+01  7.457231e+00           1.018102e+01     9.906009e+00
# min    3.000000e+01  2.000000e+01           0.000000e+00     0.000000e+00
# 25%    5.200000e+01  3.200000e+01           1.700000e+01     3.000000e+00
# 50%    6.600000e+01  4.000000e+01           2.400000e+01     9.000000e+00
# 75%    7.800000e+01  4.000000e+01           3.200000e+01     1.700000e+01
# max    8.900000e+01  4.000000e+01           4.000000e+01     4.300000e+01
#
#            LATITUDE     LONGITUDE       cluster         usage
# count  2.059656e+06  2.059656e+06  2.059656e+06  2.059655e+06
# mean   5.334644e+01 -6.252491e+00  1.000299e+00  3.119712e-01
# std    8.394812e-03  1.264777e-02  8.163989e-01  8.637711e-01
# min    5.333521e+01 -6.265305e+00  0.000000e+00  0.000000e+00
# 25%    5.333876e+01 -6.264828e+00  0.000000e+00  0.000000e+00
# 50%    5.334712e+01 -6.262003e+00  1.000000e+00  0.000000e+00
# 75%    5.335346e+01 -6.237153e+00  2.000000e+00  0.000000e+00
# max    5.335997e+01 -6.234749e+00  2.000000e+00  3.800000e+01

# %%
data.head()
# Out:
#          STATION ID LAST UPDATED              NAME  BIKE STANDS  \
# 1963957          52     23:59:58  YORK STREET EAST           32
# 2046855          52     23:59:58  YORK STREET EAST           32
# 1774322          52     23:59:57  YORK STREET EAST           32
# 1785069          52     23:59:54  YORK STREET EAST           32
# 1834379          52     23:59:53  YORK STREET EAST           32
#
#          AVAILABLE BIKE STANDS  AVAILABLE BIKES STATUS           ADDRESS  \
# 1963957                     27                5   Open  York Street East
# 2046855                     31                1   Open  York Street East
# 1774322                     31                1   Open  York Street East
# 1785069                     14               18   Open  York Street East
# 1834379                     11               21   Open  York Street East
#
#           LATITUDE  LONGITUDE  ...  FULL  EMPTY DAY_NUMBER  DAY_TYPE  \
# 1963957  53.338757  -6.262003  ...     0      0          3   Weekday
# 2046855  53.338757  -6.262003  ...     0      0          6    Sunday
# 1774322  53.338757  -6.262003  ...     0      0          2   Weekday
# 1785069  53.338757  -6.262003  ...     0      0          5  Saturday
# 1834379  53.338757  -6.262003  ...     0      0          5  Saturday
#
#           TIME_TYPE  HOUR  MONTH       CLUSTER_GROUP  YEAR usage
# 1963957  Overnight     23      1   Overnight Weekday  2021   NaN
# 2046855  Overnight     23     11    Overnight Sunday  2021  -4.0
# 1774322  Overnight     23      2   Overnight Weekday  2019   0.0
# 1785069  Overnight     23      3  Overnight Saturday  2019  17.0
# 1834379  Overnight     23     10  Overnight Saturday  2019   3.0
#
# [5 rows x 26 columns]

# %%
ct1 = pd.crosstab(index = data['STATION ID'], columns = data['NAME'])
ct1
# Out:
# NAME        FITZWILLIAM SQUARE EAST  HANOVER QUAY  MATER HOSPITAL  \
# STATION ID
# 30                                0             0               0
# 52                                0             0               0
# 66                                0             0               0
# 68                                0        343626               0
# 78                                0             0          342870
# 89                           342454             0               0
#
# NAME        NEW CENTRAL BANK  PARNELL SQUARE NORTH  YORK STREET EAST
# STATION ID
# 30                         0                343825                 0
# 52                         0                     0            343681
# 66                    343200                     0                 0
# 68                         0                     0                 0
# 78                         0                     0                 0
# 89                         0                     0                 0

# %% [markdown]
# Based on the clustering the location stations choosen were:
# - 'HANOVER QUAY' in Grand Canal Dock (blue) + FITZWILLIAM SQUARE EAST
# - 'YORK STREET EAST' in south Dublin  (red) + 'NEW CENTRAL BANK'
# - 'MATER HOSPITAL'- north side, hospital (green) (rotunda parnell st north)

# %%
locations  = data[['LATITUDE', 'LONGITUDE', 'cluster']].drop_duplicates()
#data.sample(50)
colordict = {0: 'blue', 1: 'red', 2: 'green'}
dublin_map = folium.Map([53.345, -6.2650], zoom_start=13.0)

for LATITUDE, LONGITUDE, cluster in zip(locations['LATITUDE'],locations['LONGITUDE'],locations['cluster']):
    folium.CircleMarker(
        [LATITUDE, LONGITUDE],
        color = 'b',
        radius = 8,
        fill_color=colordict[cluster],
        fill=True,
        fill_opacity=0.9
        ).add_to(dublin_map)
dublin_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aff2f697773c9747f1317dbf80888312 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aff2f697773c9747f1317dbf80888312&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aff2f697773c9747f1317dbf80888312 = L.map(
#                 &quot;map_aff2f697773c9747f1317dbf80888312&quot;,
#                 {
#                     center: [53.345, -6.265],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13.0,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ca42ba70b495230ecba2a84135f28c9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aff2f697773c9747f1317dbf80888312);
#
#
#             var circle_marker_c8cfa9dc65d5a7a1a53a65dd46c4fc0d = L.circleMarker(
#                 [53.338757, -6.262003],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aff2f697773c9747f1317dbf80888312);
#
#
#             var circle_marker_46a76a57235fc2473b544e07631fd54f = L.circleMarker(
#                 [53.353462, -6.265305],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aff2f697773c9747f1317dbf80888312);
#
#
#             var circle_marker_fea9b1a3643991936463a505fd1e6944 = L.circleMarker(
#                 [53.347122, -6.234749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aff2f697773c9747f1317dbf80888312);
#
#
#             var circle_marker_3d1e11c110b4c3cbbe6b82ce6b35bfbc = L.circleMarker(
#                 [53.359966, -6.264828],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aff2f697773c9747f1317dbf80888312);
#
#
#             var circle_marker_e88674efd93b1e2cb04f5acb80b7373a = L.circleMarker(
#                 [53.344116, -6.237153],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aff2f697773c9747f1317dbf80888312);
#
#
#             var circle_marker_41036831fb33df1f6c54863c55a733b1 = L.circleMarker(
#                 [53.335213, -6.2509],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_aff2f697773c9747f1317dbf80888312);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen we

# %% [markdown]
# ### expl vars

# %%
#cluster stations
#data = data[data['STATUS'] == 'Open']

#?
#remove rows where no update actually occurs
#data = data.drop(['TIME'], axis = 1)
data.drop_duplicates(keep= 'first',inplace=True)

#get date and time columns
data['DATETIME'] = [dt.datetime.strptime(d, "%Y-%m-%d %H:%M:%S") for d in data["LAST UPDATED"]]
data['LAST UPDATED'] = [dt.datetime.time(d) for d in data['DATETIME']] 
data['DATE'] = [dt.datetime.date(d) for d in data['DATETIME']] 
data['date_for_merge'] = data['DATETIME'].dt.round('H')

#create important features
data['OCCUPANCY_PCT'] =  data['AVAILABLE BIKES'] / data['BIKE STANDS']
data['FULL'] = np.where(data['OCCUPANCY_PCT'] == 0, 1,0 )
data['EMPTY'] = np.where(data['OCCUPANCY_PCT'] == 1, 1,0 )

### create time aggregates needed for clustering
# weekday/saturday/sunday
data['DAY_NUMBER'] = data.DATETIME.dt.dayofweek
data['DAY_TYPE'] = np.where(data['DAY_NUMBER'] <= 4, 'Weekday', (np.where(data['DAY_NUMBER'] == 5, 'Saturday', 'Sunday')))

def bin_time(x):
    if x.time() < dt.time(6):
        return "Overnight "
    elif x.time() < dt.time(11):
        return "6AM-10AM "
    elif x.time() < dt.time(16):
        return "11AM-3PM "
    elif x.time() < dt.time(20):
        return "4PM-7PM "
    elif x.time() <= dt.time(23):
        return "8PM-11PM "
    else:
        return "Overnight "


data["TIME_TYPE"] = data['DATETIME'].apply(bin_time)
data['HOUR'] = data['DATETIME'].dt.hour
data['MONTH'] = data['DATETIME'].dt.month
#data['CLUSTER_GROUP'] = data['TIME_TYPE'] + data['DAY_TYPE']
data['YEAR'] = data['DATETIME'].dt.year

data.sample(5)
# Out:
#          STATION ID                 TIME LAST UPDATED  \
# 1062910          66  2018-11-28 07:10:02     07:08:26
# 31430            89  2018-11-19 12:20:02     12:17:11
# 1102526          66  2019-04-15 13:35:03     13:30:31
# 1658071          30  2021-06-08 23:15:02     23:05:31
# 753800           78  2019-03-26 05:30:03     05:23:36
#
#                             NAME  BIKE STANDS  AVAILABLE BIKE STANDS  \
# 1062910         NEW CENTRAL BANK           40                     35
# 31430    FITZWILLIAM SQUARE EAST           40                      7
# 1102526         NEW CENTRAL BANK           40                     23
# 1658071     PARNELL SQUARE NORTH           20                     19
# 753800            MATER HOSPITAL           40                      5
#
#          AVAILABLE BIKES STATUS                  ADDRESS   LATITUDE  ...  \
# 1062910                5   Open         New Central Bank  53.347122  ...
# 31430                 32   Open  Fitzwilliam Square East  53.335213  ...
# 1102526               17   Open         New Central Bank  53.347122  ...
# 1658071                1   Open     Parnell Square North  53.353462  ...
# 753800                35   Open           Mater Hospital  53.359966  ...
#
#              date_for_merge  OCCUPANCY_PCT  FULL  EMPTY DAY_NUMBER DAY_TYPE  \
# 1062910 2018-11-28 07:00:00          0.125     0      0          2  Weekday
# 31430   2018-11-19 12:00:00          0.800     0      0          0  Weekday
# 1102526 2019-04-15 14:00:00          0.425     0      0          0  Weekday
# 1658071 2021-06-08 23:00:00          0.050     0      0          1  Weekday
# 753800  2019-03-26 05:00:00          0.875     0      0          1  Weekday
#
#           TIME_TYPE  HOUR  MONTH  YEAR
# 1062910   6AM-10AM      7     11  2018
# 31430     11AM-3PM     12     11  2018
# 1102526   11AM-3PM     13      4  2019
# 1658071  Overnight     23      6  2021
# 753800   Overnight      5      3  2019
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Create Test and Training sets

# %%
test_data = data[data['YEAR']>= 2020]
test_data.to_csv("data/test.csv", index=False)

# %%
#training set
training_data = data[data['YEAR'] < 2020]
#len(training_data)
training_data.to_csv("data/training.csv", index=False)
# Out:
#           STATION ID    BIKE STANDS  AVAILABLE BIKE STANDS  AVAILABLE BIKES  \
# count  835815.000000  835815.000000          835815.000000    835815.000000
# mean       63.837332      35.336231              23.962945        11.200688
# std        18.884152       7.451848              11.886056        11.550862
# min        30.000000      20.000000               0.000000         0.000000
# 25%        52.000000      32.000000              16.000000         1.000000
# 50%        68.000000      40.000000              24.000000         7.000000
# 75%        78.000000      40.000000              35.000000        19.000000
# max        89.000000      40.000000              40.000000        43.000000
#
#             LATITUDE      LONGITUDE        cluster          usage  \
# count  835815.000000  835815.000000  835815.000000  835814.000000
# mean       53.346441      -6.252486       1.000020       0.449690
# std         0.008398       0.012647       0.816449       1.090021
# min        53.335213      -6.265305       0.000000       0.000000
# 25%        53.338757      -6.264828       0.000000       0.000000
# 50%        53.347122      -6.250900       1.000000       0.000000
# 75%        53.353462      -6.237153       2.000000       1.000000
# max        53.359966      -6.234749       2.000000      38.000000
#
#        OCCUPANCY_PCT           FULL          EMPTY     DAY_NUMBER  \
# count  835815.000000  835815.000000  835815.000000  835815.000000
# mean        0.305725       0.176549       0.019115       2.987064
# std         0.304569       0.381286       0.136931       2.008107
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.050000       0.000000       0.000000       1.000000
# 50%         0.200000       0.000000       0.000000       3.000000
# 75%         0.500000       0.000000       0.000000       5.000000
# max         1.075000       1.000000       1.000000       6.000000
#
#                 HOUR          MONTH           YEAR
# count  835815.000000  835815.000000  835815.000000
# mean       11.466518       7.489102    2018.686551
# std         6.913193       3.406383       0.463895
# min         0.000000       1.000000    2018.000000
# 25%         5.000000       5.000000    2018.000000
# 50%        11.000000       8.000000    2019.000000
# 75%        17.000000      10.000000    2019.000000
# max        23.000000      12.000000    2019.000000

# %%
pd.crosstab(index=test_data['NAME'], columns = data['cluster'])
# Out:
# cluster                     0.0     1.0     2.0
# NAME
# FITZWILLIAM SQUARE EAST  200977       0       0
# HANOVER QUAY             202443       0       0
# MATER HOSPITAL                0       0  201473
# NEW CENTRAL BANK              0  201856       0
# PARNELL SQUARE NORTH          0       0  202393
# YORK STREET EAST              0  202376       0

# %%
#print(training_data.describe())
pd.crosstab(index=training_data['NAME'], columns=training_data['YEAR'])
pd.crosstab(index=training_data['NAME'], columns=[training_data['BIKE STANDS'],training_data['cluster']])
pd.crosstab(training_data['NAME'], training_data['BIKE STANDS'],training_data['cluster'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 4
#       2 pd.crosstab(index=training_data['NAME'], columns=training_data['YEAR'])
#       3 pd.crosstab(index=training_data['NAME'], columns=[training_data['BIKE STANDS'],training_data['cluster']])
# ----> 4 pd.crosstab(training_data['NAME'], training_data['BIKE STANDS'],training_data['cluster'])
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py:653, in crosstab(index, columns, values, rownames, colnames, aggfunc, margins, margins_name, dropna, normalize)
#     650     raise ValueError("aggfunc cannot be used without values.")
#     652 if values is not None and aggfunc is None:
# --> 653     raise ValueError("values cannot be used without an aggfunc.")
#     655 if not is_nested_list_like(index):
#     656     index = [index]
#
# ValueError: values cannot be used without an aggfunc.

# %% [markdown]
# ## model results

# %%
# Out:
# CLUSTER_GROUP                NAME  STATION ID   LATITUDE  LONGITUDE  \
# 0                   AVONDALE ROAD         108  53.359406  -6.276142
# 1                   BENSON STREET          90  53.344154  -6.233451
# 2                 BLACKHALL PLACE          88  53.348801  -6.281637
# 7347391                 0   Open   Fitzwilliam Square East  53.335213
# 2530657                 8   Open              Hanover Quay  53.344116
# 10374461               13   Open              Hanover Quay  53.344116
# 5295853                13   Open   Fitzwilliam Square East  53.335213
# 734944                  9   Open   Fitzwilliam Square East  53.335213
# 761176                 12   Open  St James Hospital (Luas)  53.341358
# 4479757                 3   Open  St James Hospital (Luas)  53.341358
# 5136553                 9   Open  St James Hospital (Luas)  53.341358
# 7342117                19   Open              Hanover Quay  53.344116
# 7408632                24   Open  St James Hospital (Luas)  53.341358
# 8420963                 8   Open  St James Hospital (Luas)  53.341358
# 2970694                 0   Open              Hanover Quay  53.344116
# 2002496                15   Open   Fitzwilliam Square East  53.335213
# 3942815                18   Open              Hanover Quay  53.344116
# 1764388                32   Open              Hanover Quay  53.344116
# 4262346                 4   Open   Fitzwilliam Square East  53.335213
# 1562915                28   Open              Hanover Quay  53.344116
# 10601325               15   Open  St James Hospital (Luas)  53.341358
# 4387694                 0   Open   Fitzwilliam Square East  53.335213
# 6023375                11   Open   Fitzwilliam Square East  53.335213
# 7410830                 7   Open   Fitzwilliam Square East  53.335213
# 4538223                12   Open              Hanover Quay  53.344116
# 6843499                 0   Open  St James Hospital (Luas)  53.341358
# 7664254                 6   Open   Fitzwilliam Square East  53.335213
# 8042229                16   Open  St James Hospital (Luas)  53.341358
# 1798126                 3   Open   Fitzwilliam Square East  53.335213
# 5860826                18   Open   Fitzwilliam Square East  53.335213
# 7002518                 4   Open   Fitzwilliam Square East  53.335213
# 8892845                15   Open              Hanover Quay  53.344116
#
#           LONGITUDE
# 1297811   -6.292951
# 7912383   -6.237153
# 7474125   -6.250900
# 6117533   -6.250900
# 8525422   -6.237153
# 575641    -6.237153
# 143323    -6.237153
# 4450560   -6.250900
# 2216607   -6.237153
# 7373851   -6.237153
# 8991135   -6.292951
# 9169856   -6.237153
# 1568291   -6.250900
# 943076    -6.292951
# 5792671   -6.237153
# 9056837   -6.250900
# 1418928   -6.292951
# 5201578   -6.250900
# 9426472   -6.292951
# 7151876   -6.237153
# 8227665   -6.237153
# 7347391   -6.250900
# 2530657   -6.237153
# 10374461  -6.237153
# 5295853   -6.250900
# 734944    -6.250900
# 761176    -6.292951
# 4479757   -6.292951
# 5136553   -6.292951
# 7342117   -6.237153
# 7408632   -6.292951
# 8420963   -6.292951
# 2970694   -6.237153
# 2002496   -6.250900
# 3942815   -6.237153
# 1764388   -6.237153
# 4262346   -6.250900
# 1562915   -6.237153
# 10601325  -6.292951
# 4387694   -6.250900
# 6023375   -6.250900
# 7410830   -6.250900
# 4538223   -6.237153
# 6843499   -6.292951
# 7664254   -6.250900
# 8042229   -6.292951
# 1798126   -6.250900
# 5860826   -6.250900
# 7002518   -6.250900
# 8892845   -6.237153

# %%
#df.drop(columns=["ADDRESS","LATITUDE","LONGITUDE","LAST UPDATED","NAME","STATION ID","AVAILABLE BIKE STANDS","STATUS"],axis=1,inplace=True)
#df["TIME"]=pd.to_datetime(df["TIME"])  
#df.sort_values(by=['TIME'],inplace=True)
#df["GAP AMOUNT"]=df["TIME"].diff().dt.seconds/60
